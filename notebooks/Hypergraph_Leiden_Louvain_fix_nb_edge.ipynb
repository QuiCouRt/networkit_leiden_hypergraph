# %%
# This file contains the results of the tests of the Louvain and Leiden algorithms on hypergraphs

import numpy as np
import matplotlib.pyplot as plt

# majority modularity totally weighted 
# gamma modularity = 1
# gamma cut = 1/vol(V)
# random order
# 10 iterations max

# The hypergraphs were randomly generated with d_max = 5 (the max order of edges) 
#SimpleHypergraphGenerator g(numNodes, numEdges, 5, false, none);


# Run for 100 nodes and 1000 hyperedges
Louvain_for_100 = np.array([0.193781, 0.192922, 0.223158, 0.189256, 0.224570, 0.242903, 0.212995, 0.208881, 0.196310, 0.192889, 0.183875, 0.211716, 0.195496, 0.211805, 0.210051, 0.217520, 0.201738, 0.184657, 0.208751, 0.173517, 0.199370, 0.206638, 0.198498, 0.205523, 0.192772, 0.203462, 0.228824, 0.191557, 0.205351, 0.191532])
Leiden_for_100 = np.array([0.204849, 0.198591, 0.199479, 0.189455, 0.190130, 0.213752, 0.218527, 0.197362, 0.196489, 0.188205, 0.186733, 0.220129, 0.209595, 0.201196, 0.216448, 0.196852, 0.213973, 0.184472, 0.194923, 0.191966, 0.214287, 0.200246, 0.205694, 0.203150, 0.218529, 0.177616, 0.213414, 0.191410, 0.184887, 0.191803 ])
mean_louvain_for_100 = np.mean(Louvain_for_100)
mean_leiden_for_100 = np.mean(Leiden_for_100)

std_leiden_for_100 = np.nanstd(Leiden_for_100)  / np.sqrt(np.size(Leiden_for_100))
std_louvain_for_100 = np.nanstd(Louvain_for_100)  / np.sqrt(np.size(Louvain_for_100))

# Run for 430 nodes and 1000 hyperedges
Louvain_for_430 = np.array([0.402364, 0.413918, 0.400493, 0.396485, 0.370942, 0.442262, 0.404267, 0.389858, 0.368197, 0.378232, 0.400556, 0.401058, 0.391649, 0.393187, 0.396528, 0.415285, 0.394515, 0.405030, 0.405765, 0.416403, 0.412372, 0.382118, 0.388769, 0.417624, 0.409190, 0.424873, 0.438912, 0.385597, 0.423429, 0.414115])
Leiden_for_430 = np.array([0.416735, 0.427019, 0.432444, 0.412021, 0.412755, 0.425370, 0.443400, 0.411888, 0.400350, 0.415383, 0.437432, 0.408875, 0.410988, 0.400807, 0.428674, 0.414452, 0.434890, 0.411756, 0.406146, 0.434793, 0.435336, 0.433813, 0.410447, 0.420973, 0.414888, 0.440429, 0.440745, 0.424972, 0.413622, 0.416548])
mean_louvain_for_430 = np.mean(Louvain_for_430)
mean_leiden_for_430 = np.mean(Leiden_for_430)

std_leiden_for_430 = np.nanstd(Leiden_for_430)  / np.sqrt(np.size(Leiden_for_430))
std_louvain_for_430 = np.nanstd(Louvain_for_430)  / np.sqrt(np.size(Louvain_for_430))

# Run for 760 nodes and 1000 hyperedges
Louvain_for_760 = np.array([0.341741, 0.368116, 0.344939, 0.358514, 0.350366, 0.346594, 0.358522, 0.353171, 0.391412, 0.364436, 0.341541, 0.317601, 0.344002, 0.354965, 0.355786, 0.338319, 0.351263, 0.303421, 0.349782, 0.345440, 0.352939, 0.332605, 0.354345, 0.329933, 0.344781, 0.315329, 0.368081, 0.359471, 0.336394, 0.330747])
Leiden_for_760 = np.array([0.354592, 0.370982, 0.357394, 0.343238, 0.366142, 0.362164, 0.357306, 0.408660, 0.433658, 0.392061, 0.359718, 0.316686, 0.353544, 0.361539, 0.350911, 0.333022, 0.357618, 0.305291, 0.342040, 0.347952, 0.353188, 0.331881, 0.353410, 0.323358, 0.306149, 0.313978, 0.375345, 0.362657, 0.331363, 0.333450])
mean_louvain_for_760 = np.mean(Louvain_for_760)
mean_leiden_for_760 = np.mean(Leiden_for_760)

std_leiden_for_760 = np.nanstd(Leiden_for_760)  / np.sqrt(np.size(Leiden_for_760))
std_louvain_for_760 = np.nanstd(Louvain_for_760)  / np.sqrt(np.size(Louvain_for_760))

# Run for 1090 nodes and 1000 hyperedges
Louvain_for_1090  = np.array([0.313756, 0.340605, 0.318356, 0.331163, 0.335408, 0.351271, 0.342750, 0.358396, 0.305151, 0.349201, 0.303558, 0.315107, 0.323137, 0.319763, 0.322625, 0.330259, 0.354055, 0.337465, 0.342133, 0.329751, 0.297760, 0.370712, 0.350512, 0.287909, 0.321277, 0.337101, 0.348945, 0.307381, 0.356406, 0.353308])
Leiden_for_1090 = np.array([0.313774, 0.338666, 0.318295, 0.333214, 0.335388, 0.355068, 0.342684, 0.362449, 0.305224, 0.352850, 0.305480, 0.313187, 0.325213, 0.319739, 0.324173, 0.330260, 0.354431, 0.335583, 0.342168, 0.327790, 0.302334, 0.369267, 0.349006, 0.289843, 0.323323, 0.340890, 0.348928, 0.303495, 0.358594, 0.353417])
mean_louvain_for_1090 = np.mean(Louvain_for_1090)
mean_leiden_for_1090 = np.mean(Leiden_for_1090)

std_leiden_for_1090 = np.nanstd(Leiden_for_1090)  / np.sqrt(np.size(Leiden_for_1090))
std_louvain_for_1090 = np.nanstd(Louvain_for_1090)  / np.sqrt(np.size(Louvain_for_1090))

# Run for 1420 nodes and 1000 hyperedges
Louvain_for_1420 = np.array([0.323324, 0.319949, 0.339170, 0.321429, 0.342698, 0.328799, 0.315585, 0.347295, 0.352413, 0.353972, 0.340948, 0.312425, 0.345078, 0.338898, 0.315130, 0.317525, 0.339443, 0.318207, 0.341499, 0.320322, 0.321342, 0.326135, 0.350440, 0.326544, 0.333490, 0.345505, 0.365929, 0.334526, 0.348476, 0.324389])
Leiden_for_1420 = np.array([0.323317, 0.319970, 0.341163, 0.321436, 0.338682, 0.326912, 0.315590, 0.347317, 0.354480, 0.352426, 0.340964, 0.310465, 0.345078, 0.342891, 0.315114, 0.317551, 0.339468, 0.318213, 0.341493, 0.320337, 0.324870, 0.328194, 0.350504, 0.324601, 0.335429, 0.345521, 0.366024, 0.334540, 0.346527, 0.324414])
mean_louvain_for_1420 = np.mean(Louvain_for_1420)
mean_leiden_for_1420 = np.mean(Leiden_for_1420)

std_leiden_for_1420 = np.nanstd(Leiden_for_1420)  / np.sqrt(np.size(Leiden_for_1420))
std_louvain_for_1420 = np.nanstd(Louvain_for_1420)  / np.sqrt(np.size(Louvain_for_1420))

# Run for 1750 nodes and 1000 hyperedges
Louvain_for_1750 = np.array([0.325231, 0.303102, 0.329670, 0.330466, 0.341993, 0.362911, 0.333012, 0.349611, 0.314484, 0.328401, 0.338406, 0.330650, 0.344417, 0.324517, 0.301148, 0.355280, 0.335961, 0.322028, 0.341144, 0.345560, 0.348450, 0.321833, 0.348624, 0.326400, 0.342677, 0.380804, 0.330960, 0.339261, 0.351136, 0.320205])
Leiden_for_1750 = np.array([0.325228, 0.303104, 0.329661, 0.330469, 0.341998, 0.362931, 0.333010, 0.349597, 0.314482, 0.330342, 0.338402, 0.332224, 0.344432, 0.324514, 0.301147, 0.357292, 0.335969, 0.322032, 0.341148, 0.345557,0.348455, 0.321847, 0.348628, 0.326401, 0.342688, 0.380847, 0.332928, 0.339251, 0.353270, 0.320197])
mean_louvain_for_1750 = np.mean(Louvain_for_1750)
mean_leiden_for_1750 = np.mean(Leiden_for_1750)

std_leiden_for_1750 = np.nanstd(Leiden_for_1750)  / np.sqrt(np.size(Leiden_for_1750))
std_louvain_for_1750 = np.nanstd(Louvain_for_1750)  / np.sqrt(np.size(Louvain_for_1750))

# Run for 2080 nodes and 1000 hyperedges
Louvain_for_2080 = np.array([0.335339, 0.340795, 0.355546, 0.347998, 0.353316, 0.325098, 0.342170, 0.336532, 0.343221, 0.359972, 0.317255, 0.347315, 0.320244, 0.336889, 0.326515, 0.316162, 0.338020, 0.359896, 0.319143, 0.322165, 0.325279, 0.308155, 0.321424, 0.316504, 0.356926, 0.313275, 0.333868, 0.330872, 0.320933, 0.339217])
Leiden_for_2080 = np.array([0.335340, 0.340805, 0.355555, 0.348008, 0.353339, 0.325100, 0.343798, 0.336545, 0.343222, 0.359984, 0.315275, 0.347313, 0.320252, 0.335235, 0.326521, 0.316168, 0.338028, 0.359914, 0.319143, 0.322168, 0.325283, 0.310147, 0.321418, 0.316516, 0.356938, 0.313272, 0.333880, 0.330873, 0.324868, 0.339219])
mean_louvain_for_2080 = np.mean(Louvain_for_2080)
mean_leiden_for_2080 = np.mean(Leiden_for_2080)

std_leiden_for_2080 = np.nanstd(Leiden_for_2080)  / np.sqrt(np.size(Leiden_for_2080))
std_louvain_for_2080 = np.nanstd(Louvain_for_2080)  / np.sqrt(np.size(Louvain_for_2080))

# Run for 2410 nodes and 1000 hyperedges
Louvain_for_2410 = np.array([0.349800, 0.315986, 0.344282, 0.333028, 0.369052, 0.352790, 0.364764, 0.327620, 0.357607, 0.288968, 0.313074, 0.350425, 0.342074, 0.328593, 0.345728, 0.340263, 0.317865, 0.305123, 0.291785, 0.316391, 0.330763, 0.359233, 0.361571, 0.351561, 0.326220, 0.338697, 0.334819, 0.303444, 0.340867, 0.331858])
Leiden_for_2410 = np.array([0.349801, 0.315983, 0.344280, 0.333023, 0.369057, 0.352782, 0.364772, 0.329594, 0.357594, 0.289989, 0.313074, 0.350423, 0.340064, 0.328599, 0.344155, 0.340260, 0.317866, 0.305126, 0.291786, 0.316396, 0.330765, 0.359233, 0.359491, 0.351551, 0.326220, 0.338709, 0.334823, 0.303442, 0.338850, 0.331859])
mean_louvain_for_2410 = np.mean(Louvain_for_2410)
mean_leiden_for_2410 = np.mean(Leiden_for_2410)

std_leiden_for_2410 = np.nanstd(Leiden_for_2410)  / np.sqrt(np.size(Leiden_for_2410))
std_louvain_for_2410 = np.nanstd(Louvain_for_2410)  / np.sqrt(np.size(Louvain_for_2410))

# Run for 2740 nodes and 1000 hyperedges
Louvain_for_2740 = np.array([0.363313, 0.347388, 0.339792, 0.331112, 0.363015, 0.320630, 0.295615, 0.342868, 0.335559, 0.304309, 0.326458, 0.350972, 0.338601, 0.330095, 0.348837, 0.327001, 0.335361, 0.329626, 0.349305, 0.323835, 0.325457, 0.352762, 0.322528, 0.315354, 0.335580, 0.343270, 0.340261, 0.343974, 0.346736, 0.312835])
Leiden_for_2740 = np.array([0.363313, 0.347389, 0.339796, 0.331112, 0.363018, 0.320633, 0.295613, 0.342867, 0.335562, 0.304311, 0.326461, 0.350971, 0.338606, 0.329688, 0.348840, 0.326999, 0.333329, 0.329628, 0.349307, 0.323834, 0.325455, 0.352766, 0.322531, 0.315353, 0.335592, 0.343272, 0.340260, 0.343973, 0.346735, 0.312837])
mean_louvain_for_2740 = np.mean(Louvain_for_2740)
mean_leiden_for_2740 = np.mean(Leiden_for_2740)

std_leiden_for_2740 = np.nanstd(Leiden_for_2740)  / np.sqrt(np.size(Leiden_for_2740))
std_louvain_for_2740 = np.nanstd(Louvain_for_2740)  / np.sqrt(np.size(Louvain_for_2740))



# >>>>> PRINT A PLOT :
louvain = np.array([mean_louvain_for_100, mean_louvain_for_430, mean_louvain_for_760, mean_louvain_for_1090, mean_louvain_for_1420, mean_louvain_for_1750, mean_louvain_for_2080, mean_louvain_for_2740, mean_louvain_for_2740])
leiden = np.array([mean_leiden_for_100, mean_leiden_for_430, mean_leiden_for_760, mean_leiden_for_1090, mean_leiden_for_1420, mean_leiden_for_1750, mean_leiden_for_2080, mean_leiden_for_2410, mean_leiden_for_2740])
nb_nodes = np.array([100, 430, 760, 1090, 1420, 1750, 2080, 2410, 2740])

interval_louvain = np.array([std_louvain_for_100, std_louvain_for_430, std_louvain_for_760,std_louvain_for_1090, std_louvain_for_1420, std_louvain_for_1750, std_louvain_for_2080, std_louvain_for_2410, std_louvain_for_2740])
interval_leiden = np.array([std_leiden_for_100, std_leiden_for_430, std_leiden_for_760, std_leiden_for_1090, std_leiden_for_1420,std_leiden_for_1750,std_leiden_for_2080,std_leiden_for_2410, std_leiden_for_2740])

x = leiden -louvain
m = np.mean(x)

print("The gain in modularity between Leiden and Louvain is on average ", m)

y_error_louvain = np.array([interval_louvain, interval_louvain])
y_error_leiden = np.array([interval_leiden, interval_leiden])

plt.errorbar(nb_nodes, louvain, yerr = y_error_louvain, fmt ='-o', label="Louvain")
plt.errorbar(nb_nodes,leiden, yerr = y_error_leiden, fmt ='-^', label="Leiden")
leg = plt.legend()
#plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.title("Comparison Louvain and Leiden for fix nb od edges (=1000)")
plt.xlabel("Number of nodes")
plt.ylabel("Majority modularity")
plt.savefig('Compare.png', dpi=1000)
plt.show()
# Out:
# The gain in modularity between Leiden and Louvain is on average  0.002382122222222249
