174 ,0.399745 ,0.479992 ,0.562467 ,0.468725 ,0.679730 ,0.509334 ,0.519885 ,0.649288 ,0.530947 ,0.616526 ,0.421573 ,0.554704 ,0.509059 ,0.464475 ,0.572998 ,0.544063 ,0.460435 ,0.585867 ,0.561544 ,0.555748 ,0.613553 ,0.600779 ,0.520434 ,0.574002 ,0.534552 ,0.533506 ,0.534317 ,0.555272 ,0.432869 ,0.516355 ,0.455960])
mean_louvain_for_100 = np.mean(Louvain_for_100)
mean_leiden_for_100 = np.mean(Leiden_for_100)

std_leiden_for_100 = np.nanstd(Leiden_for_100)  / np.sqrt(np.size(Leiden_for_100))
std_louvain_for_100 = np.nanstd(Louvain_for_100)  / np.sqrt(np.size(Louvain_for_100))

# Run for 760 nodes and 760 hyperedges
Louvain_for_760 = np.array([0.567198 , 0.479566 , 0.523174 , 0.526936 , 0.560941 , 0.559521 , 0.547190 , 0.540007 , 0.535533 , 0.561226 , 0.532927 , 0.554269 , 0.519274 , 0.504335 , 0.541430 , 0.517508 , 0.552513 , 0.552264 , 0.553694 , 0.523772 ])
Leiden_for_760 = np.array([0.567221 , 0.479568 , 0.523249 , 0.526990 , 0.563460 , 0.559509 , 0.547263 , 0.540096 , 0.535518 , 0.561395 , 0.532963 , 0.554242 , 0.519278 , 0.502121 , 0.541453 , 0.517499 , 0.552522 , 0.552226 , 0.553667 , 0.523795 ])
mean_louvain_for_760 = np.mean(Louvain_for_760)
mean_leiden_for_760 = np.mean(Leiden_for_760)

std_leiden_for_760 = np.nanstd(Leiden_for_760)  / np.sqrt(np.size(Leiden_for_760))
std_louvain_for_760 = np.nanstd(Louvain_for_760)  / np.sqrt(np.size(Louvain_for_760))

# Run for 1420 nodes and 1420 hyperedges
Louvain_for_1420 = np.array([0.542937 , 0.517775 , 0.542573 , 0.553341 , 0.540769 , 0.512502 , 0.507932 , 0.580666 , 0.532361 , 0.538669 , 0.552296 , 0.540803 , 0.532758 , 0.548152 , 0.527164 , 0.542123 , 0.550986 , 0.542920 , 0.562315 , 0.547427 ])
Leiden_for_1420 = np.array([0.542937 , 0.517788 , 0.542573 , 0.551974 , 0.540773 , 0.512495 , 0.5079355 , 0.580709 , 0.532355 , 0.538703 , 0.552293 , 0.540800 , 0.532764 , 0.548121 , 0.527168 , 0.542155 , 0.550992 , 0.544673 , 0.562355 , 0.547475 ])
mean_louvain_for_1420 = np.mean(Louvain_for_1420)
mean_leiden_for_1420 = np.mean(Leiden_for_1420)

std_leiden_for_1420 = np.nanstd(Leiden_for_1420)  / np.sqrt(np.size(Leiden_for_1420))
std_louvain_for_1420 = np.nanstd(Louvain_for_1420)  / np.sqrt(np.size(Louvain_for_1420))

# Run for 2080 nodes and 2080 hyperedges
Louvain_for_2080 = np.array([0.548498, 0.538921, 0.532186, 0.525050, 0.540793, 0.542015, 0.520031, 0.540385, 0.552581, 0.547788, 0.532962, 0.533183, 0.536043, 0.545274, 0.533808])
Leiden_for_2080 = np.array([0.548498, 0.538941, 0.532194, 0.525062, 0.540840, 0.542008, 0.520030, 0.540392, 0.552561, 0.547796, 0.532983, 0.533190, 0.536061, 0.545279, 0.533811])
mean_louvain_for_2080 = np.mean(Louvain_for_2080)
mean_leiden_for_2080 = np.mean(Leiden_for_2080)

std_leiden_for_2080 = np.nanstd(Leiden_for_2080)  / np.sqrt(np.size(Leiden_for_2080))
std_louvain_for_2080 = np.nanstd(Louvain_for_2080)  / np.sqrt(np.size(Louvain_for_2080))

# Run for 2740 nodes and 2740 hyperedges
Louvain_for_2740 = np.array([0.544328, 0.518681, 0.548321, 0.539589, 0.552162, 0.529775, 0.560137, 0.543054, 0.530327, 0.542858, 0.548143, 0.551208, 0.530137, 0.544295, 0.523029])
Leiden_for_2740 = np.array([0.544330, 0.518685, 0.548315, 0.540497, 0.552167, 0.529059, 0.560866, 0.543060, 0.530321, 0.542863, 0.548142, 0.550300, 0.530866, 0.544295, 0.523033])
mean_louvain_for_2740 = np.mean(Louvain_for_2740)
mean_leiden_for_2740 = np.mean(Leiden_for_2740)

std_leiden_for_2740 = np.nanstd(Leiden_for_2740)  / np.sqrt(np.size(Leiden_for_2740))
std_louvain_for_2740 = np.nanstd(Louvain_for_2740)  / np.sqrt(np.size(Louvain_for_2740))

# Run for 3400 nodes and 3400 hyperedges
Louvain_for_3400 = np.array([0.540737, 0.523849, 0.547970, 0.528410, 0.545260, 0.550090 ])
Leiden_for_3400 = np.array([0.540733, 0.523847, 0.548556, 0.528414, 0.545262, 0.550084 ])
mean_louvain_for_3400 = np.mean(Louvain_for_3400)
mean_leiden_for_3400 = np.mean(Leiden_for_3400)

std_leiden_for_3400 = np.nanstd(Leiden_for_3400)  / np.sqrt(np.size(Leiden_for_3400))
std_louvain_for_3400 = np.nanstd(Louvain_for_3400)  / np.sqrt(np.size(Louvain_for_3400))

# Run for 4060 nodes and 4060 hyperedges
Louvain_for_4060 = np.array([0.545900, 0.545184, 0.523922, 0.545165, 0.540392, 0.540018])
Leiden_for_4060 = np.array([0.545908, 0.545187, 0.523925, 0.545161, 0.540882, 0.540021 ])
mean_louvain_for_4060 = np.mean(Louvain_for_4060)
mean_leiden_for_4060 = np.mean(Leiden_for_4060)

std_leiden_for_4060 = np.nanstd(Leiden_for_4060)  / np.sqrt(np.size(Leiden_for_4060))
std_louvain_for_4060 = np.nanstd(Louvain_for_4060)  / np.sqrt(np.size(Louvain_for_4060))

# Run for 4720 nodes and 4720 hyperedges
Louvain_for_4720 = np.array([0.547863, 0.551970, 0.540664, 0.530530, 0.537838, 0.524925])
Leiden_for_4720 = np.array([0.547862, 0.551973,  0.540663, 0.530527, 0.537841, 0.524923])
mean_louvain_for_4720 = np.mean(Louvain_for_4720)
mean_leiden_for_4720 = np.mean(Leiden_for_4720)

std_leiden_for_4720 = np.nanstd(Leiden_for_4720)  / np.sqrt(np.size(Leiden_for_4720))
std_louvain_for_4720 = np.nanstd(Louvain_for_4720) / np.sqrt(np.size(Louvain_for_4720))

# Run for 5380 nodes and 5380 hyperedges
Louvain_for_5380 = np.array([0.534306, 0.540237, 0.548700, 0.536438, 0.549606, 0.539397])
Leiden_for_5380 = np.array([0.534304, 0.539773,  0.548702, 0.536441, 0.549606, 0.539396])
mean_louvain_for_5380 = np.mean(Louvain_for_5380)
mean_leiden_for_5380 = np.mean(Leiden_for_5380)

std_leiden_for_5380 = np.nanstd(Leiden_for_5380) / np.sqrt(np.size(Leiden_for_5380))
std_louvain_for_5380 = np.nanstd(Louvain_for_5380)  / np.sqrt(np.size(Louvain_for_5380))


# >>>>> PRINT A PLOT :
louvain = np.array([mean_louvain_for_100, mean_louvain_for_760,mean_louvain_for_1420, mean_louvain_for_2080, mean_louvain_for_2740, mean_louvain_for_3400, mean_louvain_for_4060, mean_louvain_for_4720, mean_louvain_for_5380])
leiden = np.array([mean_leiden_for_100, mean_leiden_for_760,mean_leiden_for_1420,mean_leiden_for_2080, mean_leiden_for_2740, mean_leiden_for_3400, mean_leiden_for_4060, mean_leiden_for_4720, mean_leiden_for_5380])
nb_nodes = np.array([100, 760, 1420, 2080, 2740, 3400, 4060, 4720, 5380])

interval_louvain = np.array([std_louvain_for_100,std_louvain_for_760,std_louvain_for_1420,std_louvain_for_2080,std_louvain_for_2740,std_louvain_for_3400,std_louvain_for_4060,std_louvain_for_4720,std_louvain_for_5380])
interval_leiden = np.array([std_leiden_for_100,std_leiden_for_760,std_leiden_for_1420,std_leiden_for_2080,std_leiden_for_2740,std_leiden_for_3400,std_leiden_for_4060,std_leiden_for_4720,std_leiden_for_5380])

x = leiden -louvain
m = np.mean(x)

print("The gain in modularity between Leiden and Louvain is on average ", m)

y_error_louvain = np.array([interval_louvain/2, interval_louvain/2])
y_error_leiden = np.array([interval_leiden/2, interval_leiden/2])

plt.errorbar(nb_nodes, louvain, yerr = y_error_louvain, fmt ='-o', label="Louvain")
plt.errorbar(nb_nodes,leiden, yerr = y_error_leiden, fmt ='-^', label="Leiden")
leg = plt.legend()
#plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.title("Comparison Louvain and Leiden")
plt.xlabel("Number of nodes (=Nb of edges)")
plt.ylabel("Majority modularity")
plt.savefig('Compare.png', dpi=1000)
plt.show()
# Out:
# The gain in modularity between Leiden and Louvain is on average  0.00018818277777778015
