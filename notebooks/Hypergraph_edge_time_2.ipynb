Louvain_for_760 = np.array([0.426139, 0.435114, 0.404489, 0.398971, 0.396303, 0.426895, 0.411435, 0.381282, 0.403594, 0.395343, 0.425017, 0.411344, 0.445802, 0.446766, 0.404145, 0.392098, 0.375473, 0.410610, 0.412238, 0.409219, 0.421059, 0.435813, 0.407296, 0.383445, 0.420613, 0.429396, 0.414063, 0.385949, 0.390233, 0.446852, 0.422929, 0.393897, 0.414291, 0.413841, 0.435706, 0.419870, 0.378657, 0.377703, 0.462710, 0.396485, 0.452958, 0.435108, 0.388704, 0.402887, 0.377458, 0.414361, 0.367301, 0.410002, 0.372283, 0.419113])
Leiden_for_760 = np.array([0.427869, 0.439536, 0.467307, 0.417746, 0.427402, 0.444769, 0.453298, 0.470102, 0.470237, 0.444924, 0.448700, 0.455888, 0.433317, 0.447698, 0.407679, 0.451446, 0.420773, 0.468275, 0.426259, 0.421184, 0.450106, 0.449372, 0.438141, 0.477237, 0.452425, 0.439907, 0.443829, 0.444948, 0.421250, 0.441667, 0.413657, 0.429089, 0.436890, 0.437163, 0.408997, 0.435990, 0.456737, 0.436297, 0.446995, 0.422140, 0.460363, 0.421597, 0.443106, 0.446120, 0.445109, 0.430387, 0.437416, 0.450002, 0.425338, 0.436363])
mean_louvain_for_760 = np.mean(Louvain_for_760)
mean_leiden_for_760 = np.mean(Leiden_for_760)

std_leiden_for_760 = np.nanstd(Leiden_for_760)  / np.sqrt(np.size(Leiden_for_760))
std_louvain_for_760 = np.nanstd(Louvain_for_760)  / np.sqrt(np.size(Louvain_for_760))

# Run for 1090 nodes and 2180 hyperedges
Louvain_for_1090  = np.array([0.397597, 0.401901, 0.410852, 0.411832, 0.389975, 0.438992, 0.369662, 0.397883, 0.408336, 0.417265, 0.413981, 0.420798, 0.418198, 0.401572, 0.426110, 0.415861, 0.434906, 0.405602, 0.403058, 0.402279, 0.404086, 0.381250, 0.389682, 0.400095, 0.415042, 0.366310, 0.421724, 0.417286, 0.399376, 0.405523])
Leiden_for_1090 = np.array([0.399801, 0.449111, 0.458080, 0.436455, 0.433703, 0.439338, 0.441647, 0.428027, 0.411081, 0.442636, 0.428146, 0.448559, 0.448959, 0.432160, 0.440110, 0.437009, 0.445168, 0.440755, 0.448951, 0.435282, 0.435119, 0.439554, 0.465390, 0.420139, 0.449552,0.435996, 0.434678, 0.448363, 0.423046, 0.442313])
mean_louvain_for_1090 = np.mean(Louvain_for_1090)
mean_leiden_for_1090 = np.mean(Leiden_for_1090)

std_leiden_for_1090 = np.nanstd(Leiden_for_1090)  / np.sqrt(np.size(Leiden_for_1090))
std_louvain_for_1090 = np.nanstd(Louvain_for_1090)  / np.sqrt(np.size(Louvain_for_1090))

# Run for 1420 nodes and 2840 hyperedges
Louvain_for_1420 = np.array([0.416433, 0.370610, 0.413331, 0.400935, 0.391795, 0.427537, 0.429442, 0.367328, 0.435821, 0.405568, 0.389196, 0.399428, 0.387415, 0.378045, 0.377861, 0.399461, 0.368931, 0.383243, 0.403907, 0.401339, 0.422660, 0.393070, 0.378752, 0.426485, 0.389048, 0.405596, 0.390369, 0.396319, 0.378661, 0.392267])
Leiden_for_1420 = np.array([0.425959, 0.439957, 0.446018, 0.428308, 0.435707, 0.450372, 0.440555, 0.432462, 0.441592, 0.432298, 0.440103, 0.450924, 0.439579, 0.439866, 0.435136, 0.437828, 0.442940, 0.440063, 0.435419, 0.438227,0.438100, 0.450588, 0.434688, 0.433157, 0.435125, 0.431222, 0.450446, 0.445819, 0.432476, 0.415421])
mean_louvain_for_1420 = np.mean(Louvain_for_1420)
mean_leiden_for_1420 = np.mean(Leiden_for_1420)

std_leiden_for_1420 = np.nanstd(Leiden_for_1420)  / np.sqrt(np.size(Leiden_for_1420))
std_louvain_for_1420 = np.nanstd(Louvain_for_1420)  / np.sqrt(np.size(Louvain_for_1420))

# Run for 1750 nodes and 3500 hyperedges
Louvain_for_1750 = np.array([0.425376, 0.402612, 0.416974, 0.396544, 0.417063, 0.427961, 0.421002, 0.429114, 0.386016, 0.428848, 0.380755, 0.409864, 0.364049, 0.378298, 0.422956, 0.381476, 0.391840, 0.408076, 0.384947, 0.368399])
Leiden_for_1750 = np.array([0.426545, 0.440393, 0.423352, 0.397085, 0.416801, 0.430213, 0.438074, 0.429089, 0.441300, 0.437471, 0.429860, 0.434603, 0.420891, 0.424215, 0.419572, 0.439064, 0.422229, 0.453597, 0.439574, 0.427511])
mean_louvain_for_1750 = np.mean(Louvain_for_1750)
mean_leiden_for_1750 = np.mean(Leiden_for_1750)

std_leiden_for_1750 = np.nanstd(Leiden_for_1750)  / np.sqrt(np.size(Leiden_for_1750))
std_louvain_for_1750 = np.nanstd(Louvain_for_1750)  / np.sqrt(np.size(Louvain_for_1750))

# Run for 2080 nodes and 4160 hyperedges
Louvain_for_2080 = np.array([0.416023, 0.399517, 0.376450, 0.413314, 0.421667, 0.390600, 0.403934, 0.417096, 0.386228, 0.384986, 0.350972, 0.411155, 0.410941, 0.392973, 0.364353, 0.380748, 0.385551, 0.377068, 0.371982, 0.376545])
Leiden_for_2080 = np.array([0.411091, 0.426944, 0.436325, 0.445786, 0.439387, 0.432874, 0.431926, 0.416373, 0.436096, 0.430257, 0.435929, 0.411264, 0.442080, 0.419727, 0.428126, 0.454464, 0.412865, 0.415678, 0.439782, 0.442034])
mean_louvain_for_2080 = np.mean(Louvain_for_2080)
mean_leiden_for_2080 = np.mean(Leiden_for_2080)

std_leiden_for_2080 = np.nanstd(Leiden_for_2080)  / np.sqrt(np.size(Leiden_for_2080))
std_louvain_for_2080 = np.nanstd(Louvain_for_2080)  / np.sqrt(np.size(Louvain_for_2080))

# Run for 2410 nodes and 4820 hyperedges
Louvain_for_2410 = np.array([0.353986, 0.396725, 0.388915, 0.373643, 0.398285, 0.392578, 0.395261, 0.389975, 0.391461, 0.379028, 0.366942, 0.440740, 0.364626, 0.388880, 0.374400, 0.375796, 0.359543, 0.400099, 0.410071, 0.374639])
Leiden_for_2410 = np.array([0.407872, 0.450708, 0.429970, 0.414571, 0.429455, 0.420745, 0.421536, 0.426963, 0.436239, 0.422970, 0.417489, 0.424148, 0.426448, 0.400178, 0.411660, 0.429795, 0.426739, 0.417470, 0.421058, 0.415543])
mean_louvain_for_2410 = np.mean(Louvain_for_2410)
mean_leiden_for_2410 = np.mean(Leiden_for_2410)

std_leiden_for_2410 = np.nanstd(Leiden_for_2410)  / np.sqrt(np.size(Leiden_for_2410))
std_louvain_for_2410 = np.nanstd(Louvain_for_2410)  / np.sqrt(np.size(Louvain_for_2410))

# Run for 2740 nodes and 5480 hyperedges
Louvain_for_2740 = np.array([0.409636, 0.361930, 0.366213, 0.384324, 0.379164, 0.377640, 0.338399, 0.385540, 0.380012, 0.386729])
Leiden_for_2740 = np.array([0.422606, 0.426965, 0.433175, 0.432219, 0.403644, 0.391149, 0.426319, 0.416071, 0.402607, 0.408924])
mean_louvain_for_2740 = np.mean(Louvain_for_2740)
mean_leiden_for_2740 = np.mean(Leiden_for_2740)

std_leiden_for_2740 = np.nanstd(Leiden_for_2740)  / np.sqrt(np.size(Leiden_for_2740))
std_louvain_for_2740 = np.nanstd(Louvain_for_2740)  / np.sqrt(np.size(Louvain_for_2740))



# >>>>> PRINT A PLOT :
louvain = np.array([mean_louvain_for_100, mean_louvain_for_430, mean_louvain_for_760, mean_louvain_for_1090, mean_louvain_for_1420, mean_louvain_for_1750, mean_louvain_for_2080, mean_louvain_for_2410, mean_louvain_for_2740])
leiden = np.array([mean_leiden_for_100, mean_leiden_for_430, mean_leiden_for_760, mean_leiden_for_1090, mean_leiden_for_1420, mean_leiden_for_1750, mean_leiden_for_2080, mean_leiden_for_2410, mean_leiden_for_2740])
nb_nodes = np.array([100, 430, 760, 1090, 1420, 1750, 2080, 2410, 2740])

interval_louvain = np.array([std_louvain_for_100, std_louvain_for_430, std_louvain_for_760,std_louvain_for_1090, std_louvain_for_1420, std_louvain_for_1750, std_louvain_for_2080, std_louvain_for_2410, std_louvain_for_2740])
interval_leiden = np.array([std_leiden_for_100, std_leiden_for_430, std_leiden_for_760, std_leiden_for_1090, std_leiden_for_1420,std_leiden_for_1750,std_leiden_for_2080,std_leiden_for_2410, std_leiden_for_2740])

x = leiden -louvain
m = np.mean(x)

print("The gain in modularity between Leiden and Louvain is on average ", m)

y_error_louvain = np.array([interval_louvain, interval_louvain])
y_error_leiden = np.array([interval_leiden, interval_leiden])

#plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax2 = ax1.twiny()
ax2.plot([100*2, 430*2, 760*2, 1090*2, 1420*2, 1750*2, 2080*2, 2410*2, 2740*2], [0.37]*9, color='white')
ax2.set_xlabel("Number of edges")

ax1.errorbar(nb_nodes, louvain, yerr = y_error_louvain, fmt ='-o', label="Louvain")
ax1.errorbar(nb_nodes,leiden, yerr = y_error_leiden, fmt ='-^', label="Leiden")
leg = ax1.legend()
ax1.set_xlabel("Number of nodes")
ax1.set_ylabel("Majority modularity")
ax1.set_title("Comparison of Louvain and Leiden")

plt.savefig('Compare.png', dpi=1000)
#ax2.cla()
plt.show()
# Out:
# The gain in modularity between Leiden and Louvain is on average  0.03359607259259259
